# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

launch_counts = df.set_index('Rocket')['Launches'].sort_values()
launch_counts.plot(kind='bar')
plt.title("Number Launches per Rocket")
plt.xlabel("Launches")
plt.ylabel("Rocket")
plt.show()

payloads = df.set_index('Rocket')['Payload'].sort_values()
payloads.plot(kind='bar')
plt.title("Max Payload per Rocket")
plt.xlabel("Payload")
plt.ylabel("Rocket")
plt.show()
